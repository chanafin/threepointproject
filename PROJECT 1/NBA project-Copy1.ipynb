# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt

closed_file = 'NBA PROJECTS.csv'

nba = pd.read_csv(closed_file)

nba = nba.loc[(nba['Tm'] != 'TOT')& (nba['Year'] >= 1990)] 
nba
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm     G    GS  \
# 9547         9547  1990.0         Mark Acres   C  27.0  ORL  80.0  50.0
# 9548         9548  1990.0      Michael Adams  PG  27.0  DEN  79.0  74.0
# 9549         9549  1990.0       Mark Aguirre  SF  30.0  DET  78.0  40.0
# 9550         9550  1990.0        Danny Ainge  PG  30.0  SAC  75.0  68.0
# 9551         9551  1990.0        Mark Alarie  PF  26.0  WSB  82.0  10.0
# ...           ...     ...                ...  ..   ...  ...   ...   ...
# 24686       24686  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0
# 24687       24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0
# 24688       24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0
# 24689       24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0
# 24690       24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0
#
#            MP   PER  ...    FT%    ORB    DRB    TRB    AST    STL   BLK  \
# ...

# %%
nba.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
threes = nba.groupby('Year').sum()['3PA']
threeline = threes.plot(kind = 'line')
print(threeline)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
threeteam = nba.groupby('Tm').sum()['WS']
teamsthree = pd.DataFrame(threeteam)

teamsthree.sort_values(by = 'WS', ascending = False)
# Out:
#          WS
# Tm
# TOT  2041.2
# SAS  1550.4
# UTA  1338.0
# HOU  1298.7
# PHO  1294.6
# POR  1291.3
# CHI  1269.7
# IND  1268.8
# LAL  1268.7
# MIA  1242.4
# DET  1206.8
# BOS  1194.7
# CLE  1191.9
# DAL  1157.7
# NYK  1133.9
# ATL  1130.6
# ORL  1118.2
# GSW  1085.3
# DEN  1044.7
# MIL  1030.4
# SAC  1005.3
# LAC   991.2
# PHI   981.3
# MIN   955.5
# SEA   888.3
# NJN   836.9
# TOR   830.1
# WAS   706.3
# MEM   636.4
# CHH   518.2
# OKC   458.9
# NOH   359.4
# CHA   299.7
# WSB   256.9
# BRK   168.0
# NOP   147.4
# CHO   126.1
# VAN   121.4
# NOK    72.3

# %%
player = input('Which Player would you like to study?')
indplayer = nba.loc[nba['Player']== player]
plt.plot(indplayer['Year'], indplayer['USG%'], color = 'Red')
# Out:
# Which Player would you like to study?James Harden

# %%
SF = nba.loc[nba['Pos']== 'SF']
PG = nba.loc[nba['Pos']== 'PG']
SG = nba.loc[nba['Pos']== 'SG']
PF = nba.loc[nba['Pos']== 'PG']
C = nba.loc[nba['Pos']== 'C']

# %%
PG3 = PG.groupby('Year').sum()['3PA']
SG3 = SG.groupby('Year').sum()['3PA']
SF3 = SF.groupby('Year').sum()['3PA']
PF3 = PF.groupby('Year').sum()['3PA']
C3 = C.groupby('Year').sum()['3PA']

# %%
C3.plot(kind = 'line')
