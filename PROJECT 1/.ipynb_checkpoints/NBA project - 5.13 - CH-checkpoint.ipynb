# %%
# !pip install sportsreference

import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
from scipy.stats import linregress
from scipy import stats

#Call the data from the player data .csv and truncate to only include 1989-90 seasons onward
closed_file = 'NBA PROJECTS.csv'
players = pd.read_csv(closed_file)
players = players.loc[(players['Tm'] != 'TOT')& (players['Year'] >= 1990)]
# Out:
# Requirement already satisfied: sportsreference in c:\users\chris\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: requests>=2.18.4 in c:\users\chris\anaconda3\lib\site-packages (from sportsreference) (2.22.0)
# Requirement already satisfied: pandas>=0.24.1 in c:\users\chris\anaconda3\lib\site-packages (from sportsreference) (0.25.1)
# Requirement already satisfied: pyquery>=1.4.0 in c:\users\chris\anaconda3\lib\site-packages (from sportsreference) (1.4.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\chris\anaconda3\lib\site-packages (from requests>=2.18.4->sportsreference) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chris\anaconda3\lib\site-packages (from requests>=2.18.4->sportsreference) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\chris\anaconda3\lib\site-packages (from requests>=2.18.4->sportsreference) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\chris\anaconda3\lib\site-packages (from requests>=2.18.4->sportsreference) (2.8)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\chris\anaconda3\lib\site-packages (from pandas>=0.24.1->sportsreference) (2.8.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\chris\anaconda3\lib\site-packages (from pandas>=0.24.1->sportsreference) (1.16.5)
# Requirement already satisfied: pytz>=2017.2 in c:\users\chris\anaconda3\lib\site-packages (from pandas>=0.24.1->sportsreference) (2019.3)
# Requirement already satisfied: cssselect>0.7.9 in c:\users\chris\anaconda3\lib\site-packages (from pyquery>=1.4.0->sportsreference) (1.1.0)
# Requirement already satisfied: lxml>=2.1 in c:\users\chris\anaconda3\lib\site-packages (from pyquery>=1.4.0->sportsreference) (4.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\chris\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.24.1->sportsreference) (1.12.0)

# %%
record_file = 'NBA Season Records.csv'
name_file = 'NBA Abbreviations.csv'
records = pd.read_csv(record_file)
names = pd.read_csv(name_file)

#Clean the data in the season column to go from str(2016-17) format to float(2017) format
ssns = []
for year in records['Season']:
    yr = int(year.split('-')[1])
    if ((10 <= yr) & (yr < 20)):
        ssns.append(float('20' + str(yr)))
    elif((0 <= yr) & (yr < 10)):
        ssns.append(float('200' + str(yr)))
    else:
        ssns.append(float('19' + str(yr)))
seasons = pd.Series(ssns)
records['Season'] = seasons

#Truncate the data to only represent seasons from 1989-90 onward (removing 2017-18 as it was not in the other dataframe)
records = records.loc[(records['Season'] >= 1990) & (records['Season'] <= 2017)]

#Remove the * after the team name denoting a playoff presence
records['Team'] = records['Team'].str.replace('*', '')

#Change the names of the teams on the record dataset to the abbreviations on the abbreviation dataset
records['Team'] = records['Team'].map(names.set_index('Team')['Abbreviation'])

#Special condition for "Charlotte Hornets." The name was not used contiguously, so additional conditions were needed
records.loc[(records['Team'].isnull() == True) & 
            (records['Season'] >= 2015), 'Team'] = records.loc[(records['Team'].isnull() == True) & 
                                                               (records['Season'] >= 2015), 'Team'].replace({np.nan:'CHA'})
records.loc[(records['Team'].isnull() == True) & 
            (records['Season'] < 2015), 'Team'] = records.loc[(records['Team'].isnull() == True) & 
                                                               (records['Season'] < 2015), 'Team'].replace({np.nan:'NOP'})
records = records.rename(columns = {'Team':'Tm', 'Season':'Year'})

#Denote whether the team made the playoffs that season
records['Made Playoffs'] = records['Playoffs'].notna()

# %%
#Rename some of the team abbreviations to capture recent franchise movement/rename.
players = players.replace({'Tm':{'WSB':'WAS', 'VAN': 'MEM', 'NJN': 'BRK', 'SEA': 'OKC', 
                         'CHH':'NOP', 'NOH': 'NOP', 'NOK': 'NOP', 'CHO':'CHA' }})

# %%
#Merge the season results data with the player data. Season data is duplicated for each player
nba = pd.merge(players, records, on = ['Year', 'Tm'], how = 'left')

#Write to csv for easier visualization
nba.to_csv("test_output/merge_results.csv", index=False, header=True)

# %%
nba
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm     G    GS  \
# 0            9547  1990.0         Mark Acres   C  27.0  ORL  80.0  50.0
# 1            9548  1990.0      Michael Adams  PG  27.0  DEN  79.0  74.0
# 2            9549  1990.0       Mark Aguirre  SF  30.0  DET  78.0  40.0
# 3            9550  1990.0        Danny Ainge  PG  30.0  SAC  75.0  68.0
# 4            9551  1990.0        Mark Alarie  PF  26.0  WAS  82.0  10.0
# ...           ...     ...                ...  ..   ...  ...   ...   ...
# 13772       24686  2017.0        Cody Zeller  PF  24.0  CHA  62.0  58.0
# 13773       24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0
# 13774       24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0
# 13775       24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0
# 13776       24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0
#
#            MP   PER  ...   Pace  Rel_Pace   ORtg  Rel_ORtg   DRtg  Rel_DRtg  \
# 0      1691.0   8.3  ...  104.1       5.8  105.8      -2.3  114.3       6.2
# 1      2690.0  15.4  ...  105.4       7.1  108.0      -0.1  106.7      -1.4
# 2      2005.0  15.8  ...   94.4      -3.9  109.9       1.8  103.5      -4.6
# 3      2727.0  16.1  ...   96.7      -1.6  104.8      -3.3  110.0       1.9
# 4      1893.0  14.1  ...   99.4       1.1  107.5      -0.6  109.7       1.6
# ...       ...   ...  ...    ...       ...    ...       ...    ...       ...
# 13772  1725.0  16.7  ...   95.7      -0.7  108.8       0.0  108.6      -0.2
# 13773   525.0  13.0  ...   96.8       0.4  111.2       2.4  108.4      -0.4
# 13774   108.0   7.3  ...   96.8       0.4  103.7      -5.1  110.5       1.7
# 13775   843.0   6.9  ...   95.3      -1.1  107.4      -1.4  107.0      -1.8
# 13776   609.0  17.0  ...   98.5       2.1  106.0      -2.8  113.0       4.2
#
#                      Playoffs                              Coaches  \
# 0                         NaN                    M. Guokas (18-64)
# 1      Lost W. Conf. 1st Rnd.                       D. Moe (43-39)
# 2                  Won Finals                      C. Daly (59-23)
# 3                         NaN  J. Reynolds (7-21) D. Motta (16-38)
# 4                         NaN                    W. Unseld (31-51)
# ...                       ...                                  ...
# 13772                     NaN                  S. Clifford (36-46)
# 13773    Lost E. Conf. Finals                   B. Stevens (53-29)
# 13774                     NaN                     F. Vogel (29-53)
# 13775  Lost E. Conf. 1st Rnd.                   F. Hoiberg (41-41)
# 13776                     NaN                    L. Walton (26-56)
#
#                    Top WS  Made Playoffs
# 0          O. Smith (3.3)          False
# 1          F. Lever (8.8)           True
# 2      B. Laimbeer (10.1)           True
# 3         R. McCray (7.9)          False
# 4         D. Walker (6.3)          False
# ...                   ...            ...
# 13772     K. Walker (8.1)          False
# 13773    I. Thomas (12.5)           True
# 13774     E. Payton (4.4)          False
# 13775    J. Butler (13.8)           True
# 13776   L. Williams (4.9)          False
#
# [13777 rows x 69 columns]

# %%
nba.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Lg', 'W', 'L', 'W/L%',
#        'Finish', 'SRS', 'Pace', 'Rel_Pace', 'ORtg', 'Rel_ORtg', 'DRtg',
#        'Rel_DRtg', 'Playoffs', 'Coaches', 'Top WS', 'Made Playoffs'],
#       dtype='object')

# %%
years = nba.groupby(['Year']).mean()
shooting = years[['3P%']].rename(columns = {'3P%': '3P% Yr Avg'})

#shooting.plot(kind = 'line')

three_years = years['3P%']
pace_years = years['Pace']
fig, ax = plt.subplots()
ax1 = three_years.plot()
ax2 = ax1.twinx()
ax2.spines['right'].set_position(('axes', 1.0))
pace_years.plot(ax=ax2, color = 'red', xlim = 1990)
plt.grid(b = True)
plt.title('Pace and Three Point Field Goal % since 2000')
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
teams = nba.groupby(['Tm']).mean()

teamshooting = teams[['TS%', '3PA', '3P%', 'eFG%', 'WS/48', 'Pace']]

teamshooting = teamshooting.sort_values(['eFG%'], ascending = False)
teamshooting
# Out:
#           TS%        3PA       3P%      eFG%     WS/48       Pace
# Tm
# PHO  0.515472  82.343158  0.287491  0.478081  0.072324  95.369895
# OKC  0.515467  81.663755  0.268080  0.478076  0.081548  93.208515
# SAS  0.514768  72.059322  0.266654  0.477385  0.099737  91.916737
# HOU  0.514046  94.860370  0.266066  0.477217  0.078663  93.082136
# MIA  0.512808  77.316348  0.285636  0.477098  0.082790  91.125478
# BOS  0.513839  76.663180  0.260597  0.473310  0.075052  93.664017
# UTA  0.514893  63.487239  0.274371  0.472778  0.078378  91.289095
# IND  0.513224  83.721839  0.265474  0.471228  0.083552  92.570805
# DET  0.507041  77.656109  0.267817  0.469490  0.082980  90.390950
# POR  0.506182  81.926991  0.270613  0.469255  0.081312  91.778319
# GSW  0.508252  80.433735  0.278297  0.469059  0.065998  96.553012
# LAL  0.507698  87.318182  0.271719  0.468295  0.078930  93.643864
# DEN  0.505774  73.485656  0.254034  0.467926  0.059346  95.633607
# NYK  0.505006  81.471092  0.286791  0.467157  0.073218  91.883512
# WAS  0.505272  64.481481  0.253740  0.466517  0.062570  93.534156
# DAL  0.503279  79.745935  0.264034  0.464657  0.062264  92.719309
# MIL  0.502288  73.882979  0.268806  0.464229  0.063913  92.494894
# SAC  0.502468  75.176344  0.269543  0.463412  0.062024  95.032688
# MEM  0.500613  68.870466  0.260647  0.462118  0.057238  91.210881
# ORL  0.499448  82.106610  0.263915  0.461870  0.067194  93.250107
# NOP  0.499051  64.994129  0.271412  0.460893  0.054771  92.164579
# CHI  0.493930  69.642702  0.268855  0.458831  0.073098  91.999346
# TOR  0.498890  77.363184  0.265053  0.458394  0.055662  91.331841
# CHA  0.498648  79.758475  0.294176  0.458176  0.051907  91.977542
# ATL  0.497839  75.819502  0.267658  0.457623  0.064554  92.087759
# MIN  0.498858  62.589011  0.252701  0.455710  0.056070  92.692308
# PHI  0.491660  63.663984  0.254224  0.454435  0.048825  93.101207
# CLE  0.495537  71.683673  0.259690  0.454319  0.059535  91.328367
# LAC  0.493373  70.955975  0.245083  0.454051  0.048429  93.418449
# BRK  0.485702  68.553360  0.264243  0.444923  0.048180  92.629051

# %%
x = teams['eFG%']
y = teams['WS/48']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x, y)
plt.scatter(x,y, facecolors = 'red')
plt.plot(x, line, color = "blue")
plt.grid(b = True)
plt.title('Historic Team eFG% vs. Team WS/48')
plt.xlabel('Effective Field Goal %')
plt.ylabel('Win Shares per 48 minutes')

print(cor)
# Out:
# (0.8241914625349471, 2.1747037866385124e-08)

# %%
#create column in nba that adds that years avg shooting value to each row
nba_new = pd.merge(nba, shooting, on = ['Year'], how = 'left')
#write .loc where 

nba_above_avg = nba_new.loc[nba_new['3P%'] >= nba_new['3P% Yr Avg']]
nba_above_avg.loc[(nba_above_avg['Year'] == 1995) | (nba_above_avg['Year'] == 2000) | (nba_above_avg['Year'] == 2005) |
                 (nba_above_avg['Year'] == 2010) | (nba_above_avg['Year'] == 2017)]

#combined = {'Present Day' : warriors, '2010' : heat, '2005' : spurs, '2000' : lakers, '1995' : bulls}
#combined_df = pd.DataFrame(combined)
#tcombined = combined_df.transpose()
#tcombined = tcombined[::-1]
#year = combined_df.keys()
#position = 
#nba_above_avg[['Year', 'Player','3P%', '3P% Yr Avg']]
above_avg = nba_above_avg.groupby(['Year', 'Pos']).count()
graph_above_avg = above_avg['Tm']

graph_above_avg_df = pd.DataFrame(graph_above_avg)
graph_above_avg_df
#above_avg
#vg_plot = above_avg['Player']


#graph_above_avg = graph_above_avg.pivot(index = 'Year', columns = 'Pos', values = 'Player')
# Out:
#             Tm
# Year   Pos
# 1990.0 C    14
#        PF   23
#        PG   49
#        SF   41
#        SG   50
# ...         ..
# 2017.0 C    28
#        PF   61
#        PG   77
#        SF   74
#        SG   88
#
# [140 rows x 1 columns]

# %%
avgteam = nba.loc[nba["Year"] == 2016 ]
teampace = avgteam['Pace']
teams = avgteam.groupby(['Tm']).sum()
twopointatt = teams['2PA'] /82
threepointatt = teams['3PA'] /82
twopoint = teams['2P'] /82
threepoint = teams['3P'] /82
twoper = twopoint / twopointatt
threeper = threepoint / threepointatt

# %%
warriors_df = pd.read_csv("warriors")
warriors_df

for index, row in warriors_df.iterrows():
    player_id = row['PlayerID']
    results = Player(player_id)
    player_df= results.dataframe
    print(player_df[['three_point_percentage', 'three_point_attempts']])

# %%
from sportsreference.nba.roster import Player
pd.set_option('display.max_columns', None)


warriors_7 = ["curryst01",
"thompkl01",
"iguodan01",
"barneha02",
"bogutan01",
"greendr01",
"livinsh01"]

gsw = []

for i in warriors_7:
    p_object = Player(i)
    gsw_df = p_object.dataframe
    gsw_df = gsw_df.loc[['2015-16']].reset_index()
    gsw_df["Player Name"]= p_object.name
    gsw.append(gsw_df)


warriors = pd.concat(gsw)
warriors
# Out:
#    level_0 and_ones  assist_percentage  assists  block_percentage  \
# 0  2015-16     None               33.7    527.0               0.4
# 0  2015-16     None                9.8    166.0               1.4
# 0  2015-16     None               16.3    219.0               0.8
# 0  2015-16     None                7.8    117.0               0.4
# 0  2015-16     None               14.8    162.0               5.8
# 0  2015-16     None               29.0    598.0               3.0
# 0  2015-16     None               21.0    237.0               1.3
#
#   blocking_fouls  blocks  box_plus_minus  center_percentage  \
# 0           None    15.0            11.9                  0
# 0           None    49.0             1.8                  0
# 0           None    19.0             1.1                  0
# 0           None    10.0            -1.3                  0
# 0           None   114.0             2.4                  0
# 0           None   113.0             5.5                  0
# 0           None    27.0             0.3                  0
#
#    defensive_box_plus_minus  defensive_rebound_percentage  defensive_rebounds  \
# 0                       1.6                          13.6               362.0
# 0                      -1.6                          10.3               271.0
# 0                       1.3                          12.4               211.0
# 0                      -1.1                          12.4               248.0
# 0                       3.2                          26.0               371.0
# 0                       2.9                          23.0               635.0
# 0                       1.1                           8.5               127.0
#
#    defensive_win_shares  dunks  effective_field_goal_percentage  \
# 0                   4.1    7.0                            0.630
# 0                   2.6   15.0                            0.569
# 0                   2.1   49.0                            0.552
# 0                   1.9   54.0                            0.531
# 0                   2.9   78.0                            0.629
# 0                   5.1   47.0                            0.551
# 0                   1.7   36.0                            0.538
#
#    field_goal_attempts  field_goal_perc_sixteen_foot_plus_two_pointers  \
# 0               1598.0                                           0.443
# 0               1386.0                                           0.455
# 0                368.0                                           0.400
# 0                633.0                                           0.509
# 0                279.0                                           0.250
# 0                819.0                                           0.292
# 0                379.0                                           0.425
#
#    field_goal_perc_ten_to_sixteen_feet  field_goal_perc_three_to_ten_feet  \
# 0                                0.447                              0.422
# 0                                0.423                              0.336
# 0                                0.407                              0.348
# 0                                0.394                              0.409
# 0                                0.231                              0.375
# 0                                0.368                              0.339
# 0                                0.523                              0.434
#
#    field_goal_perc_zero_to_three_feet  field_goal_percentage  field_goals  \
# 0                               0.696                  0.504        805.0
# 0                               0.687                  0.470        651.0
# 0                               0.728                  0.478        176.0
# 0                               0.625                  0.466        295.0
# 0                               0.757                  0.627        175.0
# 0                               0.618                  0.490        401.0
# 0                               0.724                  0.536        203.0
#
#    free_throw_attempt_rate  free_throw_attempts  free_throw_percentage  \
# 0                    0.250                400.0                  0.908
# 0                    0.159                221.0                  0.873
# 0                    0.226                 83.0                  0.614
# 0                    0.212                134.0                  0.761
# 0                    0.179                 50.0                  0.480
# 0                    0.402                329.0                  0.696
# 0                    0.245                 93.0                  0.860
#
#    free_throws  games_played  games_started  half_court_heaves  \
# 0        363.0          79.0           79.0               11.0
# 0        193.0          80.0           80.0                4.0
# 0         51.0          65.0            1.0                3.0
# 0        102.0          66.0           59.0                0.0
# 0         24.0          70.0           66.0                0.0
# 0        229.0          81.0           81.0                1.0
# 0         80.0          78.0            3.0                1.0
#
#    half_court_heaves_made height lost_ball_turnovers  minutes_played  \
# 0                     2.0    6-3                None          2700.0
# 0                     0.0    6-6                None          2666.0
# 0                     0.0    6-6                None          1732.0
# 0                     0.0    6-8                None          2042.0
# 0                     0.0    7-0                None          1451.0
# 0                     0.0    6-6                None          2808.0
# 0                     0.0    6-7                None          1520.0
#
#                 nationality net_plus_minus  offensive_box_plus_minus  \
# 0  United States of America           None                      10.3
# 0  United States of America           None                       3.4
# 0  United States of America           None                      -0.2
# 0  United States of America           None                      -0.2
# 0                 Australia           None                      -0.9
# 0  United States of America           None                       2.6
# 0  United States of America           None                      -0.7
#
#   offensive_fouls  offensive_rebound_percentage  offensive_rebounds  \
# 0            None                           2.9                68.0
# 0            None                           1.5                35.0
# 0            None                           3.4                52.0
# 0            None                           4.3                77.0
# 0            None                           9.5               121.0
# 0            None                           5.5               134.0
# 0            None                           3.2                42.0
#
#    offensive_win_shares on_court_plus_minus other_turnovers passing_turnovers  \
# 0                  13.8                None            None              None
# 0                   5.5                None            None              None
# 0                   2.3                None            None              None
# 0                   3.1                None            None              None
# 0                   2.6                None            None              None
# 0                   6.0                None            None              None
# 0                   2.9                None            None              None
#
#    percentage_field_goals_as_dunks  percentage_of_three_pointers_from_corner  \
# 0                            0.004                                     0.129
# 0                            0.013                                     0.246
# 0                            0.141                                     0.377
# 0                            0.093                                     0.444
# 0                            0.297                                     0.000
# 0                            0.061                                     0.093
# 0                            0.106                                     0.667
#
#    percentage_shots_three_pointers  percentage_shots_two_pointers  \
# 0                            0.554                          0.446
# 0                            0.469                          0.531
# 0                            0.418                          0.582
# 0                            0.338                          0.662
# 0                            0.004                          0.996
# 0                            0.315                          0.685
# 0                            0.032                          0.968
#
#    percentage_sixteen_foot_plus_two_pointers  \
# 0                                      0.088
# 0                                      0.138
# 0                                      0.136
# 0                                      0.183
# 0                                      0.014
# 0                                      0.029
# 0                                      0.106
#
#    percentage_ten_to_sixteen_footers  percentage_three_to_ten_footers  \
# 0                              0.048                            0.084
# 0                              0.131                            0.082
# 0                              0.073                            0.063
# 0                              0.104                            0.147
# 0                              0.047                            0.258
# 0                              0.023                            0.144
# 0                              0.404                            0.201
#
#    percentage_zero_to_three_footers  personal_fouls  player_efficiency_rating  \
# 0                             0.225           161.0                      31.5
# 0                             0.182           152.0                      18.6
# 0                             0.310           102.0                      12.2
# 0                             0.227           136.0                      12.3
# 0                             0.677           221.0                      15.9
# 0                             0.488           240.0                      19.3
# 0                             0.259           140.0                      13.8
#
#    player_id  point_guard_percentage  points points_generated_by_assists  \
# 0  curryst01                       0  2375.0                        None
# 0  thompkl01                       0  1771.0                        None
# 0  iguodan01                       0   457.0                        None
# 0  barneha02                       0   774.0                        None
# 0  bogutan01                       0   375.0                        None
# 0  greendr01                       0  1131.0                        None
# 0  livinsh01                       0   488.0                        None
#
#   position  power_forward_percentage      salary  shooting_distance  \
# 0       PG                         0  11370786.0               17.4
# 0       SG                         0  15500000.0               16.5
# 0       SF                         0  11710456.0               14.5
# 0    PF-SF                         0   3873398.0               13.9
# 0        C                         0  12000000.0                2.7
# 0       PF                         0  14300000.0               10.0
# 0       PG                         0   5543725.0                9.2
#
#   shooting_fouls shooting_fouls_drawn  shooting_guard_percentage  \
# 0           None                 None                          0
# 0           None                 None                          0
# 0           None                 None                          0
# 0           None                 None                          0
# 0           None                 None                          0
# 0           None                 None                          0
# 0           None                 None                          0
#
#   shots_blocked  small_forward_percentage  steal_percentage  steals  \
# 0          None                         0               3.0   169.0
# 0          None                         0               1.1    60.0
# 0          None                         0               2.0    73.0
# 0          None                         0               1.0    41.0
# 0          None                         0               1.1    33.0
# 0          None                         0               2.0   119.0
# 0          None                         0               1.8    57.0
#
#   take_fouls team_abbreviation  three_point_attempt_rate  \
# 0       None               GSW                     0.554
# 0       None               GSW                     0.469
# 0       None               GSW                     0.418
# 0       None               GSW                     0.338
# 0       None               GSW                     0.004
# 0       None               GSW                     0.315
# 0       None               GSW                     0.032
#
#    three_point_attempts  three_point_percentage  \
# 0                 886.0                   0.454
# 0                 650.0                   0.425
# 0                 154.0                   0.351
# 0                 214.0                   0.383
# 0                   1.0                   1.000
# 0                 258.0                   0.388
# 0                  12.0                   0.167
#
#   three_point_shot_percentage_from_corner  three_pointers  \
# 0                                   0.482           402.0
# 0                                   0.419           276.0
# 0                                   0.431            54.0
# 0                                   0.358            82.0
# 0                                    None             1.0
# 0                                   0.417           100.0
# 0                                    0.25             2.0
#
#    three_pointers_assisted_percentage  total_rebound_percentage  \
# 0                               0.547                       8.6
# 0                               0.920                       6.2
# 0                               0.944                       8.2
# 0                               0.988                       8.6
# 0                               0.000                      18.3
# 0                               0.960                      14.7
# 0                               1.000                       6.0
#
#    total_rebounds  true_shooting_percentage  turnover_percentage  turnovers  \
# 0           430.0                     0.669                 12.9      262.0
# 0           306.0                     0.597                  8.5      138.0
# 0           263.0                     0.565                 16.3       79.0
# 0           325.0                     0.559                  7.6       57.0
# 0           492.0                     0.623                 21.6       83.0
# 0           769.0                     0.587                 21.2      259.0
# 0           169.0                     0.581                 15.7       78.0
#
#    two_point_attempts  two_point_percentage  two_pointers  \
# 0               712.0                 0.566         403.0
# 0               736.0                 0.510         375.0
# 0               214.0                 0.570         122.0
# 0               419.0                 0.508         213.0
# 0               278.0                 0.626         174.0
# 0               561.0                 0.537         301.0
# 0               367.0                 0.548         201.0
#
#    two_pointers_assisted_percentage  usage_percentage  \
# 0                             0.372              32.6
# 0                             0.725              26.3
# 0                             0.631              12.1
# 0                             0.634              15.9
# 0                             0.764              11.4
# 0                             0.618              18.8
# 0                             0.473              14.2
#
#    value_over_replacement_player  weight  win_shares  \
# 0                            9.5     190        17.9
# 0                            2.5     215         8.0
# 0                            1.4     215         4.4
# 0                            0.3     225         4.9
# 0                            1.6     260         5.4
# 0                            5.3     230        11.1
# 0                            0.9     192         4.6
#
#    win_shares_per_48_minutes       Player Name
# 0                      0.318     Stephen Curry
# 0                      0.144     Klay Thompson
# 0                      0.122    Andre Iguodala
# 0                      0.116   Harrison Barnes
# 0                      0.180      Andrew Bogut
# 0                      0.190    Draymond Green
# 0                      0.145  Shaun Livingston

# %%
bulls_7 = ["jordami01",
"pippesc01",
"kukocto01",
"kerrst01",
"harpero01",
"longllu01",
"rodmade01"]

chi = []

for j in bulls_7:
    p_object = Player(j)
    chi_df = p_object.dataframe
    chi_df = chi_df.loc[['1995-96']].reset_index()
    chi_df['Player Name'] = p_object.name
    chi.append(chi_df)
    
bulls = pd.concat(chi)
bulls
# Out:
#    level_0 and_ones  assist_percentage  assists  block_percentage  \
# 0  1995-96     None               21.2    352.0               1.0
# 0  1995-96     None               25.2    452.0               1.5
# 0  1995-96     None               21.0    287.0               1.0
# 0  1995-96     None               14.1    192.0               0.1
# 0  1995-96     None               15.5    208.0               1.3
# 0  1995-96     None               10.6    119.0               3.9
# 0  1995-96     None               10.0    160.0               1.0
#
#   blocking_fouls  blocks  box_plus_minus  center_percentage  \
# 0           None    42.0            10.5                  0
# 0           None    57.0             6.3                  0
# 0           None    28.0             5.4                  0
# 0           None     2.0             3.4                  0
# 0           None    32.0             2.6                  0
# 0           None    84.0            -1.6                  0
# 0           None    27.0             0.0                  0
#
#    defensive_box_plus_minus  defensive_rebound_percentage  defensive_rebounds  \
# 0                       2.2                          14.9               395.0
# 0                       1.7                          14.2               344.0
# 0                       0.9                          11.5               208.0
# 0                       1.0                           5.2                85.0
# 0                       2.6                           8.6               139.0
# 0                       1.3                          15.2               214.0
# 0                       0.3                          33.2               596.0
#
#    defensive_win_shares  dunks  effective_field_goal_percentage  \
# 0                   6.2    NaN                            0.525
# 0                   5.3    NaN                            0.525
# 0                   3.2    NaN                            0.546
# 0                   2.3    NaN                            0.633
# 0                   3.3    NaN                            0.495
# 0                   2.8    NaN                            0.482
# 0                   4.6    NaN                            0.485
#
#    field_goal_attempts  field_goal_perc_sixteen_foot_plus_two_pointers  \
# 0               1850.0                                             NaN
# 0               1216.0                                             NaN
# 0                787.0                                             NaN
# 0                482.0                                             NaN
# 0                501.0                                             NaN
# 0                502.0                                             NaN
# 0                304.0                                             NaN
#
#    field_goal_perc_ten_to_sixteen_feet  field_goal_perc_three_to_ten_feet  \
# 0                                  NaN                                NaN
# 0                                  NaN                                NaN
# 0                                  NaN                                NaN
# 0                                  NaN                                NaN
# 0                                  NaN                                NaN
# 0                                  NaN                                NaN
# 0                                  NaN                                NaN
#
#    field_goal_perc_zero_to_three_feet  field_goal_percentage  field_goals  \
# 0                                 NaN                  0.495        916.0
# 0                                 NaN                  0.463        563.0
# 0                                 NaN                  0.490        386.0
# 0                                 NaN                  0.506        244.0
# 0                                 NaN                  0.467        234.0
# 0                                 NaN                  0.482        242.0
# 0                                 NaN                  0.480        146.0
#
#    free_throw_attempt_rate  free_throw_attempts  free_throw_percentage  \
# 0                    0.355                657.0                  0.834
# 0                    0.266                324.0                  0.679
# 0                    0.339                267.0                  0.772
# 0                    0.174                 84.0                  0.929
# 0                    0.277                139.0                  0.705
# 0                    0.205                103.0                  0.777
# 0                    0.349                106.0                  0.528
#
#    free_throws  games_played  games_started  half_court_heaves  \
# 0        548.0          82.0           82.0                NaN
# 0        220.0          77.0           77.0                NaN
# 0        206.0          81.0           20.0                NaN
# 0         78.0          82.0            0.0                NaN
# 0         98.0          80.0           80.0                NaN
# 0         80.0          62.0           62.0                NaN
# 0         56.0          64.0           57.0                NaN
#
#    half_court_heaves_made height lost_ball_turnovers  minutes_played  \
# 0                     NaN    6-6                None          3090.0
# 0                     NaN    6-8                None          2825.0
# 0                     NaN   6-10                None          2103.0
# 0                     NaN    6-3                None          1919.0
# 0                     NaN    6-6                None          1886.0
# 0                     NaN    7-2                None          1641.0
# 0                     NaN    6-7                None          2088.0
#
#                 nationality net_plus_minus  offensive_box_plus_minus  \
# 0  United States of America           None                       8.3
# 0  United States of America           None                       4.6
# 0                   Croatia           None                       4.6
# 0                   Lebanon           None                       2.4
# 0  United States of America           None                       0.0
# 0                 Australia           None                      -2.9
# 0  United States of America           None                      -0.3
#
#   offensive_fouls  offensive_rebound_percentage  offensive_rebounds  \
# 0            None                           5.6               148.0
# 0            None                           6.3               152.0
# 0            None                           6.4               115.0
# 0            None                           1.5                25.0
# 0            None                           4.6                74.0
# 0            None                           7.4               104.0
# 0            None                          19.9               356.0
#
#    offensive_win_shares on_court_plus_minus other_turnovers passing_turnovers  \
# 0                  14.2                None            None              None
# 0                   7.0                None            None              None
# 0                   6.9                None            None              None
# 0                   6.0                None            None              None
# 0                   3.0                None            None              None
# 0                   0.7                None            None              None
# 0                   1.7                None            None              None
#
#    percentage_field_goals_as_dunks  percentage_of_three_pointers_from_corner  \
# 0                              NaN                                       NaN
# 0                              NaN                                       NaN
# 0                              NaN                                       NaN
# 0                              NaN                                       NaN
# 0                              NaN                                       NaN
# 0                              NaN                                       NaN
# 0                              NaN                                       NaN
#
#    percentage_shots_three_pointers  percentage_shots_two_pointers  \
# 0                              NaN                            NaN
# 0                              NaN                            NaN
# 0                              NaN                            NaN
# 0                              NaN                            NaN
# 0                              NaN                            NaN
# 0                              NaN                            NaN
# 0                              NaN                            NaN
#
#    percentage_sixteen_foot_plus_two_pointers  \
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
#
#    percentage_ten_to_sixteen_footers  percentage_three_to_ten_footers  \
# 0                                NaN                              NaN
# 0                                NaN                              NaN
# 0                                NaN                              NaN
# 0                                NaN                              NaN
# 0                                NaN                              NaN
# 0                                NaN                              NaN
# 0                                NaN                              NaN
#
#    percentage_zero_to_three_footers  personal_fouls  player_efficiency_rating  \
# 0                               NaN           195.0                      29.4
# 0                               NaN           198.0                      21.0
# 0                               NaN           150.0                      20.4
# 0                               NaN           109.0                      15.2
# 0                               NaN           137.0                      14.4
# 0                               NaN           223.0                      11.9
# 0                               NaN           196.0                      13.6
#
#    player_id  point_guard_percentage  points points_generated_by_assists  \
# 0  jordami01                       0  2491.0                        None
# 0  pippesc01                       0  1496.0                        None
# 0  kukocto01                       0  1065.0                        None
# 0   kerrst01                       0   688.0                        None
# 0  harpero01                       0   594.0                        None
# 0  longllu01                       0   564.0                        None
# 0  rodmade01                       0   351.0                        None
#
#   position  power_forward_percentage     salary  shooting_distance  \
# 0       SF                         0  3850000.0                NaN
# 0     None                         0  2925000.0                NaN
# 0       PF                         0  3560000.0                NaN
# 0       PG                         0   800000.0                NaN
# 0       PG                         0  3120000.0                NaN
# 0     None                         0  2300000.0                NaN
# 0       PF                         0  2500000.0                NaN
#
#   shooting_fouls shooting_fouls_drawn  shooting_guard_percentage  \
# 0           None                 None                          0
# 0           None                 None                          0
# 0           None                 None                          0
# 0           None                 None                          0
# 0           None                 None                          0
# 0           None                 None                          0
# 0           None                 None                          0
#
#   shots_blocked  small_forward_percentage  steal_percentage  steals  \
# 0          None                         0               3.1   180.0
# 0          None                         0               2.5   133.0
# 0          None                         0               1.6    64.0
# 0          None                         0               1.7    63.0
# 0          None                         0               2.9   105.0
# 0          None                         0               0.7    22.0
# 0          None                         0               0.9    36.0
#
#   take_fouls team_abbreviation  three_point_attempt_rate  \
# 0       None               CHI                     0.141
# 0       None               CHI                     0.330
# 0       None               CHI                     0.274
# 0       None               CHI                     0.492
# 0       None               CHI                     0.208
# 0       None               CHI                     0.000
# 0       None               CHI                     0.089
#
#    three_point_attempts  three_point_percentage  \
# 0                 260.0                   0.427
# 0                 401.0                   0.374
# 0                 216.0                   0.403
# 0                 237.0                   0.515
# 0                 104.0                   0.269
# 0                   0.0                     NaN
# 0                  27.0                   0.111
#
#   three_point_shot_percentage_from_corner  three_pointers  \
# 0                                     NaN           111.0
# 0                                     NaN           150.0
# 0                                     NaN            87.0
# 0                                     NaN           122.0
# 0                                     NaN            28.0
# 0                                    None             0.0
# 0                                     NaN             3.0
#
#   three_pointers_assisted_percentage  total_rebound_percentage  \
# 0                                NaN                      10.2
# 0                                NaN                      10.2
# 0                                NaN                       8.9
# 0                                NaN                       3.3
# 0                                NaN                       6.6
# 0                               None                      11.3
# 0                                NaN                      26.6
#
#    total_rebounds  true_shooting_percentage  turnover_percentage  turnovers  \
# 0           543.0                     0.582                  8.4      197.0
# 0           496.0                     0.551                 13.2      207.0
# 0           323.0                     0.589                 11.2      114.0
# 0           110.0                     0.663                  7.5       42.0
# 0           213.0                     0.528                 11.5       73.0
# 0           318.0                     0.515                 17.2      114.0
# 0           952.0                     0.501                 28.2      138.0
#
#    two_point_attempts  two_point_percentage  two_pointers  \
# 0              1590.0                 0.506         805.0
# 0               815.0                 0.507         413.0
# 0               571.0                 0.524         299.0
# 0               245.0                 0.498         122.0
# 0               397.0                 0.519         206.0
# 0               502.0                 0.482         242.0
# 0               277.0                 0.516         143.0
#
#    two_pointers_assisted_percentage  usage_percentage  \
# 0                               NaN              33.3
# 0                               NaN              24.4
# 0                               NaN              21.4
# 0                               NaN              12.9
# 0                               NaN              14.9
# 0                               NaN              17.8
# 0                               NaN              10.3
#
#    value_over_replacement_player  weight  win_shares  \
# 0                            9.8     195        20.4
# 0                            5.9     210        12.3
# 0                            4.0     192        10.1
# 0                            2.6     175         8.3
# 0                            2.2     185         6.3
# 0                            0.2     265         3.5
# 0                            1.1     210         6.2
#
#    win_shares_per_48_minutes     Player Name
# 0                      0.317  Michael Jordan
# 0                      0.209  Scottie Pippen
# 0                      0.231      Toni Kukoč
# 0                      0.208      Steve Kerr
# 0                      0.161      Ron Harper
# 0                      0.101     Luc Longley
# 0                      0.143   Dennis Rodman

# %%
GOAT = pd.concat([bulls, warriors])

# %%
GOAT = GOAT.rename(columns = {'level_0': 'Year'})
GOAT.columns
#assist_percentage
# Out:
# Index(['Year', 'and_ones', 'assist_percentage', 'assists', 'block_percentage',
#        'blocking_fouls', 'blocks', 'box_plus_minus', 'center_percentage',
#        'defensive_box_plus_minus', 'defensive_rebound_percentage',
#        'defensive_rebounds', 'defensive_win_shares', 'dunks',
#        'effective_field_goal_percentage', 'field_goal_attempts',
#        'field_goal_perc_sixteen_foot_plus_two_pointers',
#        'field_goal_perc_ten_to_sixteen_feet',
#        'field_goal_perc_three_to_ten_feet',
#        'field_goal_perc_zero_to_three_feet', 'field_goal_percentage',
#        'field_goals', 'free_throw_attempt_rate', 'free_throw_attempts',
#        'free_throw_percentage', 'free_throws', 'games_played', 'games_started',
#        'half_court_heaves', 'half_court_heaves_made', 'height',
#        'lost_ball_turnovers', 'minutes_played', 'nationality',
#        'net_plus_minus', 'offensive_box_plus_minus', 'offensive_fouls',
#        'offensive_rebound_percentage', 'offensive_rebounds',
#        'offensive_win_shares', 'on_court_plus_minus', 'other_turnovers',
#        'passing_turnovers', 'percentage_field_goals_as_dunks',
#        'percentage_of_three_pointers_from_corner',
#        'percentage_shots_three_pointers', 'percentage_shots_two_pointers',
#        'percentage_sixteen_foot_plus_two_pointers',
#        'percentage_ten_to_sixteen_footers', 'percentage_three_to_ten_footers',
#        'percentage_zero_to_three_footers', 'personal_fouls',
#        'player_efficiency_rating', 'player_id', 'point_guard_percentage',
#        'points', 'points_generated_by_assists', 'position',
#        'power_forward_percentage', 'salary', 'shooting_distance',
#        'shooting_fouls', 'shooting_fouls_drawn', 'shooting_guard_percentage',
#        'shots_blocked', 'small_forward_percentage', 'steal_percentage',
#        'steals', 'take_fouls', 'team_abbreviation', 'three_point_attempt_rate',
#        'three_point_attempts', 'three_point_percentage',
#        'three_point_shot_percentage_from_corner', 'three_pointers',
#        'three_pointers_assisted_percentage', 'total_rebound_percentage',
#        'total_rebounds', 'true_shooting_percentage', 'turnover_percentage',
#        'turnovers', 'two_point_attempts', 'two_point_percentage',
#        'two_pointers', 'two_pointers_assisted_percentage', 'usage_percentage',
#        'value_over_replacement_player', 'weight', 'win_shares',
#        'win_shares_per_48_minutes', 'Player Name'],
#       dtype='object')

# %%
GOAT_years = GOAT.groupby(['Year']).sum()
GOAT_years
# Out:
#          assist_percentage  assists  block_percentage  blocks  box_plus_minus  \
# Year
# 1995-96              117.6   1770.0               9.8   272.0            26.6
# 2015-16              132.4   2026.0              13.1   347.0            21.7
#
#          center_percentage  defensive_box_plus_minus  \
# Year
# 1995-96                  0                      10.0
# 2015-16                  0                       7.4
#
#          defensive_rebound_percentage  defensive_rebounds  \
# Year
# 1995-96                         102.8              1981.0
# 2015-16                         106.2              2225.0
#
#          defensive_win_shares  dunks  effective_field_goal_percentage  \
# Year
# 1995-96                  27.7    0.0                            3.691
# 2015-16                  20.4  286.0                            4.000
#
#          field_goal_attempts  field_goal_perc_sixteen_foot_plus_two_pointers  \
# Year
# 1995-96               5642.0                                           0.000
# 2015-16               5462.0                                           2.774
#
#          field_goal_perc_ten_to_sixteen_feet  \
# Year
# 1995-96                                0.000
# 2015-16                                2.793
#
#          field_goal_perc_three_to_ten_feet  \
# Year
# 1995-96                              0.000
# 2015-16                              2.663
#
#          field_goal_perc_zero_to_three_feet  field_goal_percentage  \
# Year
# 1995-96                               0.000                  3.383
# 2015-16                               4.835                  3.571
#
#          field_goals  free_throw_attempt_rate  free_throw_attempts  \
# Year
# 1995-96       2731.0                    1.965               1680.0
# 2015-16       2706.0                    1.673               1310.0
#
#          free_throw_percentage  free_throws  games_played  games_started  \
# Year
# 1995-96                  5.224       1286.0         528.0          378.0
# 2015-16                  5.192       1042.0         519.0          369.0
#
#          half_court_heaves  half_court_heaves_made  minutes_played  \
# Year
# 1995-96                0.0                     0.0         15552.0
# 2015-16               20.0                     2.0         14919.0
#
#          offensive_box_plus_minus  offensive_rebound_percentage  \
# Year
# 1995-96                      16.7                          51.7
# 2015-16                      14.3                          30.3
#
#          offensive_rebounds  offensive_win_shares  \
# Year
# 1995-96               974.0                  39.5
# 2015-16               529.0                  36.2
#
#          percentage_field_goals_as_dunks  \
# Year
# 1995-96                            0.000
# 2015-16                            0.715
#
#          percentage_of_three_pointers_from_corner  \
# Year
# 1995-96                                     0.000
# 2015-16                                     1.956
#
#          percentage_shots_three_pointers  percentage_shots_two_pointers  \
# Year
# 1995-96                             0.00                           0.00
# 2015-16                             2.13                           4.87
#
#          percentage_sixteen_foot_plus_two_pointers  \
# Year
# 1995-96                                      0.000
# 2015-16                                      0.694
#
#          percentage_ten_to_sixteen_footers  percentage_three_to_ten_footers  \
# Year
# 1995-96                               0.00                            0.000
# 2015-16                               0.83                            0.979
#
#          percentage_zero_to_three_footers  personal_fouls  \
# Year
# 1995-96                             0.000          1208.0
# 2015-16                             2.368          1152.0
#
#          player_efficiency_rating  point_guard_percentage  points  \
# Year
# 1995-96                     125.9                       0  7249.0
# 2015-16                     123.6                       0  7371.0
#
#          power_forward_percentage      salary  shooting_distance  \
# Year
# 1995-96                         0  19055000.0                0.0
# 2015-16                         0  74298365.0               84.2
#
#          shooting_guard_percentage  small_forward_percentage  \
# Year
# 1995-96                          0                         0
# 2015-16                          0                         0
#
#          steal_percentage  steals  three_point_attempt_rate  \
# Year
# 1995-96              13.4   603.0                     1.534
# 2015-16              12.0   552.0                     2.130
#
#          three_point_attempts  three_point_percentage  three_pointers  \
# Year
# 1995-96                1245.0                   2.099           501.0
# 2015-16                2175.0                   3.168           917.0
#
#          total_rebound_percentage  total_rebounds  true_shooting_percentage  \
# Year
# 1995-96                      77.1          2955.0                     3.929
# 2015-16                      70.6          2754.0                     4.181
#
#          turnover_percentage  turnovers  two_point_attempts  \
# Year
# 1995-96                 97.2      885.0              4397.0
# 2015-16                103.8      956.0              3287.0
#
#          two_point_percentage  two_pointers  two_pointers_assisted_percentage  \
# Year
# 1995-96                 3.552        2230.0                             0.000
# 2015-16                 3.865        1789.0                             4.217
#
#          usage_percentage  value_over_replacement_player  weight  win_shares  \
# Year
# 1995-96             135.0                           25.8    1432        67.1
# 2015-16             131.3                           21.5    1527        56.3
#
#          win_shares_per_48_minutes
# Year
# 1995-96                      1.370
# 2015-16                      1.215
